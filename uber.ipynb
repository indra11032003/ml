# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
#We do not want to see warnings
warnings.filterwarnings("ignore")

# %%
#import data
data = pd.read_csv("uber.csv")

# %%
#Create a data copy
df = data.copy()

# %%
#pickup_datetime is not in required data format
df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"])

# %%
#Drop the rows with missing values
df.dropna(inplace=True)

# %%
#Time to apply learning models
from sklearn.model_selection import train_test_split

# %%
#Take x as predictor variable
x = df.drop(columns=['fare_amount'])
#And y as target variable
y = df['fare_amount']

# %%
#Necessary to apply model

x['pickup_datetime'] = pd.to_numeric(pd.to_datetime(x['pickup_datetime']))
x = x.loc[:, x.columns.str.contains('^Unnamed')]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lrmodel = LinearRegression()
lrmodel.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Prediction
predict = lrmodel.predict(x_test)

# %%
predict
# Out:
# array([11.37455746, 11.35483847, 11.36541312, ..., 11.33605112,
#        11.39172073, 11.36398553])

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(predict,y_test))
# Out:
# 9.9103858428844

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rm=RandomForestRegressor(n_estimators=110)

# %%
rm.fit(x_train,y_train)

# %%
rm_predict=rm.predict(x_test)

# %%
np.sqrt(mean_squared_error(rm_predict,y_test))
